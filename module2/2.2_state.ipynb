# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.messages import HumanMessage, ToolMessage
from langgraph.checkpoint.memory import InMemorySaver
import os

load_dotenv()

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
if not OPENROUTER_API_KEY:
    raise EnvironmentError("Установите OPENROUTER_API_KEY в файле .env")


llm = ChatOpenAI(
    model="deepseek/deepseek-v3.2",
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY,
    temperature=0.0
)

# %%
from langchain.agents import AgentState

class CustomState(AgentState):
    favourite_colour: str

# %% [markdown]
# ### Инструмент для записи в состояние

# %%
from langchain.tools import tool, ToolRuntime
from langgraph.types import Command

@tool
def update_favourite_colour(favourite_colour: str, runtime: ToolRuntime) -> Command:
    """Update the favourite colour of the user in the state once they've revealed it."""
    return Command(update={
        "favourite_colour": favourite_colour,
        "messages": [ToolMessage("Successfully updated favourite colour", tool_call_id=runtime.tool_call_id)]
    })

# %%
agent = create_agent(
    model=llm,
    tools=[update_favourite_colour],
    checkpointer=InMemorySaver(),
    state_schema=CustomState
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    { "messages": [HumanMessage(content="My favourite colour is green")]},
    {"configurable": {"thread_id": "1"}}
)

print(response['messages'][-1].content)
# Out:
# Your favourite colour has been successfully updated to green!

# %%
from pprint import pprint

pprint(response)
# Out:
# {'favourite_colour': 'green',
#  'messages': [HumanMessage(content='My favourite colour is green', additional_kwargs={}, response_metadata={}, id='c4f75d4c-aca1-48d7-965e-bbf9cbef9d60'),
#               AIMessage(content="I'll update your favourite colour to green in the system.\n\n", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 330, 'total_tokens': 391, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 0.00010898, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 8.58e-05, 'upstream_inference_completions_cost': 2.318e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': None, 'id': 'gen-1767464298-y3iL0LtWORxSxyRFfaM9', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b8514-e468-7602-bbb4-e000e678f6b7-0', tool_calls=[{'name': 'update_favourite_colour', 'args': {'favourite_colour': 'green'}, 'id': 'call_f6d73b22a9ef4510ade40417', 'type': 'tool_call'}], usage_metadata={'input_tokens': 330, 'output_tokens': 61, 'total_tokens': 391, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#               ToolMessage(content='Successfully updated favourite colour', name='update_favourite_colour', id='2f5841c6-66b1-439f-92fa-8a7e58381396', tool_call_id='call_f6d73b22a9ef4510ade40417'),
#               AIMessage(content='Your favourite colour has been successfully updated to green!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 412, 'total_tokens': 423, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 0.0001113, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 0.00010712, 'upstream_inference_completions_cost': 4.18e-06}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': None, 'id': 'gen-1767464301-aujLe1f7LKPXqUi7tz8W', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8514-efa0-7f63-bba8-8a17218b1d7c-0', usage_metadata={'input_tokens': 412, 'output_tokens': 11, 'total_tokens': 423, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}})]}

# %%
response = agent.invoke(
    { 
        "messages": [HumanMessage(content="Hello, how are you?")],
        "favourite_colour": "green"
    },
    {"configurable": {"thread_id": "10"}}
)

pprint(response)
# Out:
# {'favourite_colour': 'green',
#  'messages': [HumanMessage(content='Hello, how are you?', additional_kwargs={}, response_metadata={}, id='28dcc3f6-3b82-4f30-a20c-8d5b35c74c3b'),
#               AIMessage(content="Hello! I'm doing well, thank you for asking. How are you today? Is there anything I can help you with?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 331, 'total_tokens': 358, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 9.632e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 8.606e-05, 'upstream_inference_completions_cost': 1.026e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': None, 'id': 'gen-1767464303-stk2uV7zX8zVg8uTbagl', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8514-f9ae-7770-a1f9-b499648cb8e2-0', usage_metadata={'input_tokens': 331, 'output_tokens': 27, 'total_tokens': 358, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}})]}

# %% [markdown]
# ### Инструмент для чтения из состояния

# %%
@tool
def read_favourite_colour(runtime: ToolRuntime) -> str:
    """ Read the favourite colour of the user from the state"""
    try:
        return runtime.state["favourite_colour"]
    except KeyError:
        return "No favourite colour found in state"

agent = create_agent(
    model=llm,
    tools=[update_favourite_colour, read_favourite_colour],
    checkpointer=InMemorySaver(),
    state_schema=CustomState
)

response = agent.invoke(
    { "messages": [HumanMessage(content="My favourite colour is green")]},
    {"configurable": {"thread_id": "1"}}
)

pprint(response)
# Out:
# {'favourite_colour': 'green',
#  'messages': [HumanMessage(content='My favourite colour is green', additional_kwargs={}, response_metadata={}, id='84949005-bf48-4f9e-b5f8-56925d850355'),
#               AIMessage(content="I see that you've shared your favorite color is green. Let me update that in the system for you.\n\n", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 126, 'total_tokens': 165, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 4.797e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 3.276e-05, 'upstream_inference_completions_cost': 1.521e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': None, 'id': 'gen-1767464307-iMDxDtf44S9VJLUgQudx', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b8515-0a06-7562-b778-2da9f21a8dab-0', tool_calls=[{'name': 'update_favourite_colour', 'args': {'favourite_colour': 'green'}, 'id': 'call_00_Gc3mM1Dt9CZ2GxeGjfBXBQ66', 'type': 'tool_call'}], usage_metadata={'input_tokens': 126, 'output_tokens': 39, 'total_tokens': 165, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#               ToolMessage(content='Successfully updated favourite colour', name='update_favourite_colour', id='5a1eecf3-2cb5-49fb-8724-551d1c2d86ae', tool_call_id='call_00_Gc3mM1Dt9CZ2GxeGjfBXBQ66'),
#               AIMessage(content='Great! I\'ve successfully updated your favorite color to "green" in the system. Is there anything else you\'d like to know or discuss about colors, or anything else I can help you with?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 180, 'total_tokens': 226, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 6.474e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 4.68e-05, 'upstream_inference_completions_cost': 1.794e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': None, 'id': 'gen-1767464313-NfzwyvK3VfmY9ra7CBGn', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8515-1e8a-7b83-be0b-b94e3f4dcbcf-0', usage_metadata={'input_tokens': 180, 'output_tokens': 46, 'total_tokens': 226, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}})]}

# %%
response = agent.invoke(
    { "messages": [HumanMessage(content="What's my favourite colour?")]},
    {"configurable": {"thread_id": "1"}}
)

pprint(response)
# Out:
# {'favourite_colour': 'green',
#  'messages': [HumanMessage(content='My favourite colour is green', additional_kwargs={}, response_metadata={}, id='84949005-bf48-4f9e-b5f8-56925d850355'),
#               AIMessage(content="I see that you've shared your favorite color is green. Let me update that in the system for you.\n\n", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 126, 'total_tokens': 165, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 4.797e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 3.276e-05, 'upstream_inference_completions_cost': 1.521e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': None, 'id': 'gen-1767464307-iMDxDtf44S9VJLUgQudx', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b8515-0a06-7562-b778-2da9f21a8dab-0', tool_calls=[{'name': 'update_favourite_colour', 'args': {'favourite_colour': 'green'}, 'id': 'call_00_Gc3mM1Dt9CZ2GxeGjfBXBQ66', 'type': 'tool_call'}], usage_metadata={'input_tokens': 126, 'output_tokens': 39, 'total_tokens': 165, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#               ToolMessage(content='Successfully updated favourite colour', name='update_favourite_colour', id='5a1eecf3-2cb5-49fb-8724-551d1c2d86ae', tool_call_id='call_00_Gc3mM1Dt9CZ2GxeGjfBXBQ66'),
#               AIMessage(content='Great! I\'ve successfully updated your favorite color to "green" in the system. Is there anything else you\'d like to know or discuss about colors, or anything else I can help you with?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 180, 'total_tokens': 226, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 6.474e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 4.68e-05, 'upstream_inference_completions_cost': 1.794e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': None, 'id': 'gen-1767464313-NfzwyvK3VfmY9ra7CBGn', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8515-1e8a-7b83-be0b-b94e3f4dcbcf-0', usage_metadata={'input_tokens': 180, 'output_tokens': 46, 'total_tokens': 226, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='42b7b75d-de9d-43e5-9fd9-b4fa248309bc'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 515, 'total_tokens': 580, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 38, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 0.00016635, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 0.00013905, 'upstream_inference_completions_cost': 2.73e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': '', 'id': 'gen-1767464315-Z4oCytlpOTPYvAR8kGAq', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b8515-28fc-7743-82ad-622d02561dbf-0', tool_calls=[{'name': 'read_favourite_colour', 'args': {}, 'id': '019b851539d0b7f8666651fc0cc5af2c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 515, 'output_tokens': 65, 'total_tokens': 580, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 38}}),
#               ToolMessage(content='green', name='read_favourite_colour', id='14d8a581-5d73-49b6-9995-07ba64308fc7', tool_call_id='019b851539d0b7f8666651fc0cc5af2c'),
#               AIMessage(content='Your favorite color is green!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 247, 'total_tokens': 255, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 6.734e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 6.422e-05, 'upstream_inference_completions_cost': 3.12e-06}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v3.2', 'system_fingerprint': None, 'id': 'gen-1767464319-i8SgS8BlJ9EZNeRxlsXL', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8515-38fd-73e0-b644-ce0402a3eab6-0', usage_metadata={'input_tokens': 247, 'output_tokens': 8, 'total_tokens': 255, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# Your favorite color is green!
