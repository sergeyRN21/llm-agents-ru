# %% [markdown]
# ### «Добавление веб-поиска в агента»
#
# **Цель**: сравнить поведение агента без инструментов и с инструментом веб-поиска, чтобы показать, как агент получает доступ к свежей информации.

# %%
import os
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
if not OPENROUTER_API_KEY:
    raise EnvironmentError("Установите OPENROUTER_API_KEY в файле .env")

llm = ChatOpenAI(
    model="google/gemini-2.5-flash",
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY
)

# %% [markdown]
# ### Часть 1: Агент без внешних источников

# %%
agent = create_agent(model=llm)

question = HumanMessage(content="Кто является действующим мэром Сан-Франциско?")

response = agent.invoke(
    {"messages": [question]}
)
print(response['messages'][-1].content)
# Out:
# Действующим мэром Сан-Франциско является **Лондон Брид**.
#
# Она занимает эту должность с июля 2018 года.

# %% [markdown]
# ### Часть 2: Создание инструмента веб-поиска
#
# #### Что происходит:
# 1. TavilyClient — это клиент для Tavily API, одного из лучших search API для LLM (оптимизирован под агентов, возвращает чистые результаты).
# 2. @tool превращает функцию web_search в инструмент, понятный LangChain.
# 3. Описание (docstring) говорит модели: «Этот инструмент ищет в интернете».
# 4. Тестовый вызов — проверяем, что инструмент работает сам по себе.
# #### Почему Tavily?
# - Возвращает структурированный JSON с results, answer, query.
# - Фильтрует рекламу и мусор.
# - Поддерживает deep search (платный), но даже бесплатный режим отлично работает для агентов.

# %%
tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the web information"""
    return tavily_client.search(query)

web_search.invoke("Кто является действующим мэром Сан-Франциско?")
# Out:
# {'query': 'Кто является действующим мэром Сан-Франциско?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://stmegi.com/posts/121779/merom-san-frantsisko-izbran-deniel-lure/',
#    'title': 'Мэром Сан-Франциско избран Дэниел Лурье - STMEGI',
#    'content': 'Лурье, демократ, является наследником состояния компании Levi Strauss. Он сын раввина Брайана Лурье, который занимал пост исполнительного',
#    'score': 0.9998697,
#    'raw_content': None},
#   {'url': 'https://rossaprimavera.ru/news/72bd8f9b',
#    'title': "Мэром Сан-Франциско избран наследник компании Levi's",
#    'content': 'Действующий мэр Сан-Франциско Лондон Брид уже признала поражение и поздравила Лури с победой. Лури станет первым мэром Сан-Франциско за последние 100 лет, который никогда не работал в правительстве до своего избрания. Лури является умеренным демократом и обещал избирателям расширить штат полиции, построить больше мест в приютах для бездомных, закрыть места торговли наркотиками и искоренить коррупцию в мэрии. Мы не можем рассчитывать ни на какое благополучное существование в XXI веке. Мама и папа, которые не прячутся от ребенка и друг от друга в экраны, проявляют эмоциональную отзывчивость\xa0— это условие... В ответ на задержание археолога Бутягина российские дипломаты заявили о том, что это событие является проявлением «оголт... «Ничто не мешает Зеленскому сесть на поезд и приехать в Варшаву». **ЭЛ № ФС 77-84377** от 16 января 2023 года, выдано Федеральной службой по надзору в сфере связи, информационных технологий и массовых коммуникаций (Роскомнадзор),. **ИА № ФС 77-67948** от 6 декабря 2016 года, выдано Федеральной службой по надзору в сфере связи, информационных технологий и массовых коммуникаций (Роскомнадзор).',
#    'score': 0.9995627,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': "# Office of the Mayor. Daniel Lurie is the 46th Mayor of the City and County of San Francisco. # Office of the Mayor. Daniel Lurie is the 46th Mayor of the City and County of San Francisco. ## Mayor Daniel Lurie. We are here to provide exceptional core city services that enable every San Franciscan to live safe, healthy and productive lives.Read about Mayor Lurie's priorities. Mayor Lurie Signs Street Safety Executive Directive in Major Step to Improve Public Safety in San FranciscoMayor Lurie Unveils Bust of Late Mayor Ed Lee at City HallMayor Lurie Signs Historic Family Zoning Legislation to Make City Affordable for Generations of San Franciscans. Office of the Mayor General Disclosures. Find executives directives related to the Office of Mayor Daniel Lurie. ### Office of the Mayor's newsletter. ### Mayor. Daniel Lurie is the 46th Mayor of the City and County of San Francisco. Office of the Mayor415-554-6141. Submit requests for the Office of the Mayor.",
#    'score': 0.99911696,
#    'raw_content': None},
#   {'url': 'https://www.sfgov.org/agency/mayors-office',
#    'title': "Mayor's Office | SFGOV",
#    'content': 'Visit San Francisco’s new website, SF.gov. Download viewers, Text Only, Listen Now. https://www.facebook.com/mayoredwinlee. http://www.youtube.com/user/MayorEdLee. https://www.flickr.com/photos/mayoredlee. https://plus.google.com/+MayorEdLee/about. https://www.pinterest.com/mayoredlee/. Image 1: 1 Dr. Carlton B. The Mayor leads the executive branch of the San Francisco City and County government. The Mayor has the authority to enforce city laws, and the power to either approve or veto bills. Powered by Image 2: Google TranslateTranslate. Image 3: 311 City Customer Service Agency - Service 24x7. City and County of San Francisco. Your feedback will be used to help improve Google Translate.',
#    'score': 0.99750805,
#    'raw_content': None},
#   {'url': 'https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BC%D1%8D%D1%80%D0%BE%D0%B2_%D0%A1%D0%B0%D0%BD-%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B8%D1%81%D0%BA%D0%BE',
#    'title': 'Список мэров Сан-Франциско - Википедия',
#    'content': '| 37 |  |  | Джордж Москоне 1929—1978 | 8 января 1976 года | 27 ноября 1978 года |. | * Джон Гири (1850—1851) * Чарльз Бренем") (1851; 1852—1853) * Стивен Гаррис") (1852) * Корнелиус Гаррисон") (1853—1854) * Стивен Уэбб") (1854—1855) * Джеймс ван Несс") (1855—1856) * Джордж Уилан&action=edit&redlink=1 "Уилан, Джордж (мэр) (страница отсутствует)") (1856) * Эфраим Бёрр") (1856—1859) * Генри Тешемахер") (1859—1863) * Генри Кун") (1863—1867) * Фрэнк Маккоппин") (1867—1869) * Томас Селби") (1869—1871) * Уильям Элворд") (1871—1873) * Джеймс Отис&action=edit&redlink=1 "Отис, Джеймс (мэр) (страница отсутствует)") "en:James Otis (mayor)") (1873—1875) * Джордж Хьюстон") (1875) * Эндрю Брайант") (1875—1879) * Айзек Кэллош") (1879—1881) * Морис Блейк") (1881—1883) * Вашингтон Бартлетт") (1883—1887) * Эдвард Понд") (1887—1891) * Джордж Сандерсон") (1891—1893) * Леви Эллерт") (1893—1895) * Адольф Сутро") (1895—1897) * Джеймс Фелан") (1897—1902) * Юджин Шмитц") (1902—1907) * Чарльз Бокстон") (1907) * Эдвард Тейлор") (1907—1910) * Патрик Маккарти") (1910—1912) * Джеймс Рольф&action=edit&redlink=1 "Рольф, Джеймс (политик) (страница отсутствует)") (1912—1931) * Анджело Росси") (1931—1944) * Роджер Лэпхем") (1944—1948) * Элмер Робинсон") (1948—1956) * Джордж Кристофер (1956—1964) * Джон Шелли") (1964—1968) * Джозеф Алиото") (1968—1976) * Джордж Москоне (1976—1978) * Дайэнн Файнстайн (1978—1988) * Арт Агнос (1988—1992) * Фрэнк Джордан (1992—1996) * Уилли Браун "Браун, Уилли Льюис (младший)") (1996—2004) * Гэвин Ньюсом (2004—2011) * Эдвин Ма Ли (2011—2017) * Марк Фаррелл "Фаррелл, Марк (политик)") (2018) * Лондон Брид (2018 — н.',
#    'score': 0.99648935,
#    'raw_content': None}],
#  'response_time': 0.95,
#  'request_id': '2f0f4880-74c9-458e-a4c6-95e475558be1'}

# %% [markdown]
# ### Часть 3: Агент с веб-поиском

# %%
agent = create_agent(
    model=llm,
    tools=[web_search]
)

question = HumanMessage(content="Кто является действующим мэром Сан-Франциско?")
response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Действующим мэром Сан-Франциско является Дэниел Лурье. Он стал 46-м мэром города и округа Сан-Франциско. Ранее этот пост занимала Лондон Брид.
