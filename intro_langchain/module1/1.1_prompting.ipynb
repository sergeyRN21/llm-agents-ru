# %% [markdown]
# ## Подготовка: загрузка API-ключей
#
# - Что делает: загружает переменные окружения из файла .env (например, OPENAI_API_KEY).
# - Зачем: без ключа модель не запустится.
# - Важно: убедись, что у тебя есть .env файл с нужными ключами.

# %%
from pydantic import BaseModel
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
import os
from langchain_openai import ChatOpenAI

# %%
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
if not OPENROUTER_API_KEY:
    raise EnvironmentError("Установите OPENROUTER_API_KEY в файле .env")

# %% [markdown]
# ### Что происходит:
# - Создаётся агент с моделью (имя "gemini-2.5-flash").
# - Агенту задаётся вопрос через HumanMessage.
# - Ответ приходит как второй элемент в списке messages ([0] — вопрос, [1] — ответ).
#
# **Результат**: модель отвечает фактически и честно: «У Луны нет столицы, это спутник Земли».
#
# **Вывод**: без инструкций модель ведёт себя как помощник, а не как творец.

# %%
llm = ChatOpenAI(
    model="google/gemini-2.5-flash",
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY
)

agent = create_agent(model=llm)

question = HumanMessage(content="Как называется столица Луны?")

response = agent.invoke(
    {"messages": [question]}
)
print(response['messages'][1].content)
# Out:
# Это интересный и остроумный вопрос! Однако, у Луны нет столицы, поскольку она не является страной и на ней нет ни городов, ни населения в традиционном смысле.
#
# Луна - это спутник Земли, поэтому ее можно представить как часть "владений" Земли, но не как отдельное государство со своей столицей.

# %% [markdown]
# ### 2. System Prompt — задаём роль агента
#
# ##### Что изменилось: мы передали system prompt — инструкцию на уровне системы.
#
# ##### Эффект: модель теперь «входит в роль» писателя-фантаста.
#
# ##### Вывод: system prompt — простой и мощный способ задать предназначение агента.

# %%
system_prompt = "Вы писатель-фантаст. По просьбе пользователей придумайте столицу."

scifi_agent = create_agent(
    model=llm,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Как писатель-фантаст, я всегда стараюсь добавлять детали и историю к своим творениям. Поэтому, когда я думаю о столице Луны, я представляю себе не просто город, а целую концепцию, отражающую как суровую реальность пребывания на Луне, так и мечтательную жажду человечества к освоению новых миров.
#
# Многие фантасты предложили бы столицу по имени "Артемида", "Селена" или что-то в этом духе, в честь богинь Луны. Это прекрасно, но мне хочется чего-то более *земного*, чего-то, что отражает усилия и надежды, вложенные в создание такого города.
#
# Поэтому, позвольте мне представить вам столицу Луны, которой я бы дал имя: **"Эхополис"**.
#
# ### **Эхополис (Echopolis)**
#
# **Этимология:** "Эхо" (от греческого "ēchō" – звук, отражение) и "полис" (от греческого "pólis" – город).
#
# **Значение:**
#
# *   **"Эхо"** символизирует несколько ключевых аспектов:
#     *   **Эхо Земли:** Луна — это вечное эхо, верный спутник Земли, отражающий её свет и, в каком-то смысле, её цивилизацию. Эхополис – это отражение человеческой мечты о расширении, колонизации, вынесенное за пределы родной планеты.
#     *   **Эхо прошлого:** Город хранит эхо первых шагов человечества на Луне, эхо пионеров, которые рискнули всем. Это постоянное напоминание о тех, кто проложил путь.
#     *   **Эхо будущего:** Эхополис – это старт, откуда расходятся волны исследований и открытий по всей Луне и дальше в космос. Каждый запуск, каждое новое открытие создает новое "эхо", распространяющееся в будущее.
#     *   **Акустика:** На Луне нет атмосферы, звуки не распространяются так, как на Земле. Но в искусственно созданных куполах и туннелях Эхополиса, где воздух есть, звук приобретает особенное, возможно, даже *новое* качество. Город может быть местом, где "эхо" не только метафорично, но и буквально является частью его уникальной атмосферы и дизайна. Возможно, там есть целые "звуковые сады" или "акустические галереи", где искусственно созданные звуковые ландшафты становятся формой искусства.
#
# **Краткое описание:**
#
# Эхополис – это не просто город, это комплекс взаимосвязанных, биокупольных структур и подземных тоннелей, расположенный на краю **Бассейна Моря Спокойствия** (Mare Tranquillitatis), недалеко от места посадки Аполлона-11. Его расположение выбрано стратегически: относительно плоская местность для строительства, близость к кратерам, богатым потенциальными ресурсами (водный лед в холодных ловушках), и относительно легкий доступ для первых миссий.
#
# Центральный купол, самый большой и старый, украшен парящими голографическими проекциями земных ландшафтов, позволяя жителям, скучающим по родной планете, "почувствовать" себя среди деревьев или над океаном. Подземные уровни скрывают промышленные комплексы, исследовательские лаборатории и транспортные узлы, соединяющие город с другими лунными аванпостами.
#
# В Эхополисе вы найдете как футуристические небоскребы из переработанного лунного реголита с прозрачными стенами, открывающими вид на Землю, так и уютные, тесно застроенные жилые районы, имитирующие старые земные города. Главная площадь, "Плаза Тишины", является местом встреч, где можно увидеть людей всех рас и национальностей, прибывших на Луну в поисках новой жизни, исследований или убежища. Земля гордо висит в небе над ней, напоминая о доме, откуда они пришли.
#
# Эхополис – город, который постоянно растет и развивается, его будущее все еще пишется. Он служит мостом между Землей и глубоким космосом, маяком надежды и символом неукротимого духа человечества. Его название – "Эхополис" – постоянно напоминает о его связи с прошлым и о его роли в формировании будущего.

# %% [markdown]
# #### Few-shot examples

# %%
system_prompt = """
    Вы писатель-фантаст, создайте космическую столицу по просьбе пользователей. 

Пользователь: Какая столица у Марса?
Писатель-фантаст: Марсиалис

Пользователь: Какая столица у Венеры?
Писатель-фантаст: Венеровия
"""

scifi_agent = create_agent(
    model=llm,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Писатель-фантаст: Селенит-сити

# %% [markdown]
# #### Structures prompts

# %%
system_prompt = """
Вы писатель-фантаст, создайте космическую столицу по просьбе пользователей.

Пожалуйста, придерживайтесь следующей структуры.

Название: название столицы

Местоположение: где она находится

Атмосфера: 2–3 слова, описывающие атмосферу

Экономика: основные отрасли
"""

scifi_agent = create_agent(model=llm, system_prompt=system_prompt)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Отлично! Давайте создадим космическую столицу:
#
# **Название:** Селениум Прима
#
# **Местоположение:** Кратер Тихо, Южное полушарие Луны. Большая часть города находится под поверхностью, спрятанная от суровых условий открытого космоса, но с огромными куполообразными надстройками, выходящими на поверхность и предлагающими панорамные виды на звезды и Землю.
#
# **Атмосфера:** Величественная, Невозмутимая, Технологичная
#
# **Экономика:**
#
# *   **Добыча и обработка гелия-3:** Селениум Прима является мировым центром по добыче и переработке изотопа гелия-3, который является одним из самых ценных источников термоядерного топлива в галактике. Многочисленные шахты и очистительные комплексы расположены вблизи города, а сам Селениум Прима служит логистическим и административным центром для всей отрасли.
# *   **Высокотехнологичное производство и исследования:** Благодаря стабильной и контролируемой среде, а также близости к уникальным геологическим данным, Селениум Прима привлекает ведущие космические корпорации и исследовательские институты. Здесь разрабатываются передовые материалы, робототехника, системы жизнеобеспечения для дальних космических полетов и новые энергетические технологии.
# *   **Космический туризм и рекреация:** Уникальные виды на Землю и звездное небо, а также возможность испытать низкую гравитацию, делают Селениум Прима привлекательным направлением для элитного космического туризма. Здесь расположены роскошные отели, гравитационные симуляторы, научные обсерватории для туристов и эксклюзивные экскурсии по лунной поверхности.
# *   **Финансовые услуги и торговля:** Как основная лунная столица, Селениум Прима является центром финансовой активности для всех внеземных колоний. Здесь работают крупные банки, инвестиционные фонды, биржи космических ресурсов и торговые хабы, связывающие Землю с отдаленными звездными системами.

# %% [markdown]
# #### Structured output
#
#
# - Что происходит под капотом:
#     1. LangChain преобразует CapitalInfo в JSON Schema.
#     2. Передаёт его модели через нативный structured output API (OpenAI JSON mode, Anthropic tool calling и т.д.).
#     3. Модель генерирует валидный JSON.
#     4. LangChain десериализует его в объект Python.
#
# - Преимущества:
#     - Гарантированная структура.
#     - Безопасность типов (можно использовать с mypy).
#     - Легко интегрировать в код, API, базы данных.
# - Вывод: это золотой стандарт для production-агентов, особенно в RAG, отчётах, A/B-тестах.

# %%
class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=llm,
    system_prompt="Вы писатель-фантаст. По просьбе пользователей создайте столицу.",
    response_format=CapitalInfo
)

question = HumanMessage(content="Какая столица Луны?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Селена', location='Море Спокойствия', vibe='футуристическая, технологичная', economy='добыча гелия-3, космический туризм')

# %%
response["structured_response"].name
# Out:
# 'Селена'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name}, этот город находится в {capital_location}")
# Out:
# Селена, этот город находится в Море Спокойствия
